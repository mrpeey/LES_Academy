# %%
#Part 2: Practical Implementation (60%)
#Task 1: AI-Powered Code Completion

#Compare the AI-suggested code with your manual implementation.


# AI-suggested implementation using sorted()
def sort_dicts_by_key(dicts, key):
    """
    Sort a list of dictionaries by a specific key using Python's built-in sorted().
    """
    return sorted(dicts, key=lambda d: d[key])

# %%
# Manual implementation using selection sort
def sort_dicts_by_key_manual(dicts, key):
    """
    Sort a list of dictionaries by a specific key using a manual nested loop (selection sort).
    """
    dicts = dicts.copy()
    n = len(dicts)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if dicts[j][key] < dicts[min_idx][key]:
                min_idx = j
        if min_idx != i:
            dicts[i], dicts[min_idx] = dicts[min_idx], dicts[i]
    return dicts

# %%
# Example data
data = [
    {'name': 'Alice', 'age': 30},
    {'name': 'Bob', 'age': 25},
    {'name': 'Charlie', 'age': 35}
]

# Sort by 'age' using both methods
sorted_ai = sort_dicts_by_key(data, 'age')
sorted_manual = sort_dicts_by_key_manual(data, 'age')

print('AI-suggested sorted:', sorted_ai)
print('Manual sorted:', sorted_manual)

# %% [markdown]
# #Part 2: Practical Implementation (60%)
# #Task 1: AI-Powered Code Completion
#
# #Document which version is more efficient and why.
#
# ## Analysis
# For the task of sorting a list of dictionaries by a specific key, the AI-powered code completion tool (GitHub Copilot) suggested using Python’s built-in sorted() function with a lambda function as the key. This approach is concise, readable, and leverages Python’s highly optimized Timsort algorithm, which has a time complexity of O(n log n). In contrast, the manual implementation uses a double for-loop to compare and swap elements, resulting in a time complexity of O(n²). This makes the manual approach significantly slower for larger datasets.
#
# The AI-suggested code is not only more efficient but also more maintainable and less error-prone. Built-in functions like sorted() are thoroughly tested and optimized in the Python standard library, whereas manual sorting algorithms are more susceptible to bugs and inefficiencies. Additionally, the AI-generated code is more Pythonic, adhering to best practices and idiomatic usage of the language.
#
# In summary, the AI-powered code completion provides a solution that is both faster and more reliable. It demonstrates the advantage of using modern code completion tools, which can quickly suggest optimal solutions that might take longer to write and debug manually. For production code, the AI-suggested approach is clearly superior.
